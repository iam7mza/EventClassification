# %% [markdown]
# <a href="https://colab.research.google.com/github/iam7mza/EventClassification/blob/main/FeatureSelection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Downloading the dataset from GitHub (uncomment when running on Colab)
# !git clone "https://github.com/iam7mza/EventClassification.git"
# !mv EventClassification/* ./
# !rm -rf EventClassification
# !rm -rf sample_data



############# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! no touch zone !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! #############
#importing data

import loader
import numpy as np
import pandas as pd

filepath = "Data" 
df = loader.load(filepath);
loader.clean(df); #to clean the data

df = df[df['numeric_target'] != -1]  #dropping all the unknown events

# Check unique event types and their corresponding targets
event_target_mapping = df[['event_type', 'numeric_target']].drop_duplicates().sort_values('numeric_target')
print("Event type to target mapping:")
print(event_target_mapping)

print(f'columns = {df.columns}')

############################################################
#########extracing features and values from lists###########
#############################################################`

# the chosen ones
# TheChosenOnes = ['trigE', 'trigM', 'trigP', 'lep_n','lep_pt', 'lep_eta', 'lep_phi',
#        'lep_E', 'lep_z0', 'lep_charge', 'lep_type', 'lep_isTightID',
#        'lep_ptcone30', 'lep_etcone20', 'lep_trackd0pvunbiased',
#        'lep_tracksigd0pvunbiased', 'met_et', 'met_phi', 'jet_n', 'jet_pt',
#        'jet_eta', 'jet_phi', 'jet_E', 'jet_jvt','jet_MV2c10', 'photon_n','photon_pt', 'photon_eta', 'photon_phi',
#        'photon_E', 'photon_isTightID', 'photon_ptcone30', 'photon_etcone20',
#        'photon_convType', 'largeRjet_n', 'largeRjet_pt', 'largeRjet_eta',
#        'largeRjet_phi', 'largeRjet_E', 'largeRjet_m','largeRjet_D2', 'largeRjet_tau32', 'tau_n', 'tau_pt', 'tau_eta',
#        'tau_phi', 'tau_E', 'tau_charge', 'tau_isTightID', 'tau_nTracks', 'tau_BDTid', 'ditau_m', 'lep_pt_syst',
#        'met_et_syst', 'jet_pt_syst', 'photon_pt_syst', 'largeRjet_pt_syst',
#        'tau_pt_syst']


TheChosenOnes = ['trigE', 'trigM', 'trigP', 'lep_n','lep_pt', 'lep_eta', 'lep_phi',
       'lep_E', 'lep_z0', 'lep_charge', 'lep_type', 'lep_isTightID',
       'lep_ptcone30', 'lep_etcone20', 'lep_trackd0pvunbiased',
       'lep_tracksigd0pvunbiased', 'met_et', 'met_phi', 'jet_n', 'jet_pt',
       'jet_eta', 'jet_phi', 'jet_E', 'jet_jvt','jet_MV2c10', 'photon_n','photon_pt', 'photon_eta', 'photon_phi',
       'photon_E', 'photon_isTightID', 'photon_ptcone30', 'photon_etcone20',
       'photon_convType', 'largeRjet_n', 'largeRjet_pt', 'largeRjet_eta',
       'largeRjet_phi', 'largeRjet_E', 'largeRjet_m','largeRjet_D2', 'largeRjet_tau32', 'tau_n', 'tau_pt', 'tau_eta',
       'tau_phi', 'tau_E', 'tau_charge', 'tau_isTightID', 'tau_nTracks', 'tau_BDTid', 'ditau_m']

#df[TheChosenOnes]

#extracting the features for lists (only first two elements)

#TODO: Turn into a function and make the number of cols an arg
# Separate list and scalar columns

def extract_list_features(df, list_cols, scalar_cols, n_elements=2):
    """
    Extract features from list columns with configurable number of elements.

    Parameters:
    df: DataFrame containing the data
    list_cols: List of column names that contain lists
    scalar_cols: List of column names that contain scalar values
    n_elements: Number of elements to extract from each list (max 5)

    Returns:
    DataFrame with extracted features
    """
    # Ensure n_elements is within valid range
    n_elements = min(max(n_elements, 1), 5)

    # Element names for readability
    element_names = ['first', 'second', 'third', 'fourth', 'fifth']

    extracted_data = {}

    # Add scalar columns
    for col in scalar_cols:
        extracted_data[col] = df[col]

    # Add list-derived columns
    for col in list_cols:
        for i in range(n_elements):
            col_name = f'{col}_{element_names[i]}'
            extracted_data[col_name] = df[col].apply(
                lambda x: x[i] if len(x) > i else np.nan
            )

    return pd.DataFrame(extracted_data)

# Usage with configurable number of elements
n_elements = 5  # Change this to extract 1-5 elements from each list

# Separate list and scalar columns
list_cols = []
scalar_cols = []

for col in TheChosenOnes:
    if col in df.columns:
        if isinstance(df[col].iloc[0], list):  # Use iloc[0] instead of [0]
            list_cols.append(col)
        else:
            scalar_cols.append(col)

print(f"List columns: {len(list_cols)}")
print(f"Scalar columns: {len(scalar_cols)}")
print(f"Extracting {n_elements} elements from each list column")

# Extract features with specified number of elements
df_extracted = extract_list_features(df, list_cols, scalar_cols, n_elements)

print(f"Shape after feature extraction: {df_extracted.shape}")

# Drop columns that are all zeros or nan
columns_to_drop = []
for col in df_extracted.columns:
    if df_extracted[col].isna().all():  # nan check
        columns_to_drop.append(col)
        print(f"Column {col} is all NaN, will drop it.")
    elif (df_extracted[col] == 0).all():  # zero check
        columns_to_drop.append(col)
        print(f"Column {col} is all zeros, will drop it.")


# Drop all NaN columns at once
if columns_to_drop:
    df_extracted = df_extracted.drop(columns=columns_to_drop)
    print(f"Dropped {len(columns_to_drop)} NaN columns")

print(f"Final shape: {df_extracted.shape}")
df_extracted

################################################################
## remving zero heavy columns ##################################
################################################################

# First, let's see what columns with _first we have
first_cols = [col for col in df_extracted.columns if '_first' in col]
print("Columns with '_first':")
print(first_cols)

# Features to compute TOTAL (sum)
total_base_features = ['lep_pt', 'lep_E', 'lep_charge', 'lep_ptcone30', 'lep_etcone20',
                      'jet_pt', 'jet_E', 'largeRjet_pt', 'largeRjet_E', 'largeRjet_m']

# Features to compute MEAN (average)
mean_base_features = ['lep_eta', 'lep_phi', 'lep_z0', 'jet_eta', 'jet_phi',
                     'largeRjet_eta', 'largeRjet_phi', 'lep_pt_syst', 'jet_pt_syst',
                     'largeRjet_pt_syst']

element_indicators = ['_first', '_second', '_third', '_fourth', '_fifth']

print("\nCreating TOTAL columns:")
# Create total columns
for base_feature in total_base_features:
    feature_cols = []
    for indicator in element_indicators:
        col_name = f'{base_feature}{indicator}'
        if col_name in df_extracted.columns:
            feature_cols.append(col_name)

    if len(feature_cols) > 0:
        total_col_name = f'{base_feature}_total'
        df_extracted[total_col_name] = df_extracted[feature_cols].sum(axis=1)
        print(f"  {total_col_name} from {len(feature_cols)} columns: {feature_cols}")

print("\nCreating MEAN columns:")
# Create mean columns
for base_feature in mean_base_features:
    feature_cols = []
    for indicator in element_indicators:
        col_name = f'{base_feature}{indicator}'
        if col_name in df_extracted.columns:
            feature_cols.append(col_name)

    if len(feature_cols) > 0:
        mean_col_name = f'{base_feature}_mean'
        # Calculate mean excluding zeros to avoid bias from missing particles

        ##TODO: Im not sure if replacing 0 with NaN is the best way to calculate mean here
        df_extracted[mean_col_name] = df_extracted[feature_cols].replace(0, np.nan).mean(axis=1, skipna=True).fillna(0)
        print(f"  {mean_col_name} from {len(feature_cols)} columns: {feature_cols}")

print(f"\nShape after adding totals and means: {df_extracted.shape}")

# Show new columns created
new_total_cols = [col for col in df_extracted.columns if '_total' in col]
new_mean_cols = [col for col in df_extracted.columns if '_mean' in col]
print(f"Added {len(new_total_cols)} total columns and {len(new_mean_cols)} mean columns")
print(f"Total columns: {new_total_cols}")
print(f"Mean columns: {new_mean_cols}")


############################################################
########### dropping nan heavy rows ########################
############################################################
#TODO: create cols with total values (for pt, E, et, etc.) such that when some cols are dropped, the total still exists

percentlim = 0.1  # 10% limit
nan_fraction = df_extracted.isna().mean(axis=0)  # Fraction of NaN values per column
high_nan_cols = nan_fraction[nan_fraction > percentlim].index.tolist()
print(f'{len(high_nan_cols)} cols are more than {percentlim*100:.0f}% NaN out of {len(df_extracted.columns)}')
print("NaN fractions per column:")
for col, frac in zip(df_extracted.columns, nan_fraction):
    if frac > 0:  # Only show columns with some NaN values
        print(f"  {col}: {frac*100:.1f}%")

df_extracted = df_extracted.drop(high_nan_cols, axis=1)
print(f'Columns remaining after dropping high-NaN columns: {len(df_extracted.columns)}')

df_extracted

#Dropping nan rows (if they exist)

nan_counts = df_extracted.isna().sum()
columns_with_nan = nan_counts[nan_counts > 0]
print(f"Columns with NaN values ({len(columns_with_nan)} out of {len(nan_counts)}):")
if len(columns_with_nan) > 0:
    for col, count in columns_with_nan.items():
        print(f"  {col}: {count}")
else:
    print("No columns have NaN values! YIPPIEEE!!")

# FIXED: Drop the same rows from both features AND targets
print(f"Shape before dropping NaN rows: {df_extracted.shape}")
rows_before = len(df_extracted)

# Get mask for rows WITHOUT any NaN values
valid_rows_mask = ~df_extracted.isna().any(axis=1)

# Apply the same mask to BOTH dataframes
df_extracted = df_extracted[valid_rows_mask]
df = df[valid_rows_mask]  # Drop same rows from targets!

rows_after = len(df_extracted)
print(f"Shape after dropping NaN rows: {df_extracted.shape}")
print(f"Dropped {rows_before - rows_after} rows with NaN values")
print(f"Target dataframe shape: {df.shape}")

# Verify alignment
print(f"Features and targets are aligned: {len(df_extracted) == len(df)}")
# Out:
# Found 130 CSV files
# Processing: Data/Wenu_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV280_500_CVetoBVeto)
# Processing: Data/Wenu_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV140_280_CFilterBVeto)
# Processing: Data/Wmunu_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV140_280_BFilter)
# Processing: Data/Zee_PTV70_140_BFilter.csv
#   -> Added 11 events (event name: Zee_PTV70_140_BFilter)
# Processing: Data/single_antitop_tchan_sample10000.csv
#   -> Added 10000 events (event name: single_antitop_tchan)
# Processing: Data/C1N2_WZ_400p0_0p0_3L_2L7.csv
#   -> Added 1995 events (event name: C1N2_WZ_400p0_0p0_3L_2L7)
# Processing: Data/single_top_wtchan_sample10000.csv
#   -> Added 10000 events (event name: single_top_wtchan)
# Processing: Data/single_top_schan_sample10000.csv
#   -> Added 10000 events (event name: single_top_schan)
# Processing: Data/Wtaunu_PTV0_70_BFilter.csv
#   -> Added 3 events (event name: Wtaunu_PTV0_70_BFilter)
# Processing: Data/Wmunu_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV140_280_CVetoBVeto)
# Processing: Data/Wmunu_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV1000_E_CMS)
# Processing: Data/Wenu_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV140_280_CVetoBVeto)
# Processing: Data/Zee_PTV0_70_CVetoBVeto.csv
#   -> Added 308 events (event name: Zee_PTV0_70_CVetoBVeto)
# Processing: Data/Wmunu_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV280_500_BFilter)
# Processing: Data/Wmunu_PTV0_70_CFilterBVeto.csv
#   -> Added 53 events (event name: Wmunu_PTV0_70_CFilterBVeto)
# Processing: Data/Zee_PTV70_140_CFilterBVeto.csv
#   -> Added 320 events (event name: Zee_PTV70_140_CFilterBVeto)
# Processing: Data/Ztautau_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV280_500_CVetoBVeto)
# Processing: Data/Wenu_PTV0_70_BFilter.csv
#   -> Added 194 events (event name: Wenu_PTV0_70_BFilter)
# Processing: Data/WlvZqq_sample2000.csv
#   -> Added 2000 events (event name: WlvZqq)
# Processing: Data/TT_directTT_600_1_sample2000.csv
#   -> Added 2000 events (event name: TT_directTT_600_1)
# Processing: Data/Zee_PTV0_70_CFilterBVeto.csv
#   -> Added 225 events (event name: Zee_PTV0_70_CFilterBVeto)
# Processing: Data/Ztautau_sample2000.csv
#   -> Added 2000 events (event name: Ztautau)
# Processing: Data/Wenu_PTV500_1000_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV500_1000)
# Processing: Data/Wenu_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV280_500_CFilterBVeto)
# Processing: Data/Wminusmunu_sample2000.csv
#   -> Added 2000 events (event name: Wminusmunu)
# Processing: Data/Zmumu_PTV70_140_BFilter.csv
#   -> Added 111 events (event name: Zmumu_PTV70_140_BFilter)
# Processing: Data/Zmumu_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV140_280_CFilterBVeto)
# Processing: Data/ZPrime2750_tt.csv
#   -> Added 29764 events (event name: ZPrime2750_tt)
# Processing: Data/Wmunu_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV140_280_CFilterBVeto)
# Processing: Data/Zee_PTV500_1000_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV500_1000)
# Processing: Data/Zmumu_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV280_500_BFilter)
# Processing: Data/ZPrime3000_tt.csv
#   -> Added 27368 events (event name: ZPrime3000_tt)
# Processing: Data/ZPrime400_tt.csv
#   -> Added 790 events (event name: ZPrime400_tt)
# Processing: Data/Wmunu_PTV70_140_CFilterBVeto.csv
#   -> Added 125 events (event name: Wmunu_PTV70_140_CFilterBVeto)
# Processing: Data/Wenu_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV140_280_BFilter)
# Processing: Data/Zee_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV1000_E_CMS)
# Processing: Data/Wplusenu_sample2000.csv
#   -> Added 2000 events (event name: Wplusenu)
# Processing: Data/Ztautau_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV140_280_BFilter)
# Processing: Data/Wenu_PTV0_70_CVetoBVeto.csv
#   -> Added 220 events (event name: Wenu_PTV0_70_CVetoBVeto)
# Processing: Data/Zee_PTV70_140_CVetoBVeto.csv
#   -> Added 1041 events (event name: Zee_PTV70_140_CVetoBVeto)
# Processing: Data/TT_directTT_450_1_sample2000.csv
#   -> Added 2000 events (event name: TT_directTT_450_1)
# Processing: Data/Ztautau_PTV70_140_BFilter.csv
#   -> Added 73 events (event name: Ztautau_PTV70_140_BFilter)
# Processing: Data/Wtaunu_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV140_280_CFilterBVeto)
# Processing: Data/Zmumu_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV140_280_CVetoBVeto)
# Processing: Data/Wtaunu_PTV70_140_BFilter.csv
#   -> Added 18 events (event name: Wtaunu_PTV70_140_BFilter)
# Processing: Data/Wtaunu_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV280_500_CVetoBVeto)
# Processing: Data/Wmunu_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV280_500_CFilterBVeto)
# Processing: Data/Wtaunu_PTV70_140_CVetoBVeto.csv
#   -> Added 22 events (event name: Wtaunu_PTV70_140_CVetoBVeto)
# Processing: Data/GG_ttn1_1600_5000_1_sample2000.csv
#   -> Added 2000 events (event name: GG_ttn1_1600_5000_1)
# Processing: Data/Zmumu_PTV70_140_CFilterBVeto.csv
#   -> Added 39 events (event name: Zmumu_PTV70_140_CFilterBVeto)
# Processing: Data/Ztautau_PTV0_70_BFilter.csv
#   -> Added 29 events (event name: Ztautau_PTV0_70_BFilter)
# Processing: Data/Zee_PTV0_70_BFilter.csv
#   -> Added 353 events (event name: Zee_PTV0_70_BFilter)
# Processing: Data/Ztautau_PTV70_140_CVetoBVeto.csv
#   -> Added 89 events (event name: Ztautau_PTV70_140_CVetoBVeto)
# Processing: Data/TT_directTT_500_1.csv
#   -> Added 1921 events (event name: TT_directTT_500_1)
# Processing: Data/single_antitop_wtchan_sample10000.csv
#   -> Added 10000 events (event name: single_antitop_wtchan)
# Processing: Data/Wtaunu_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV140_280_BFilter)
# Processing: Data/Ztautau_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV140_280_CFilterBVeto)
# Processing: Data/C1N2_WZ_350p0_0p0_3L_2L7.csv
#   -> Added 1613 events (event name: C1N2_WZ_350p0_0p0_3L_2L7)
# Processing: Data/C1N2_WZ_500p0_0p0_3L_2L7.csv
#   -> Added 1402 events (event name: C1N2_WZ_500p0_0p0_3L_2L7)
# Processing: Data/C1N2_WZ_100p0_0p0_3L_2L7.csv
#   -> Added 317 events (event name: C1N2_WZ_100p0_0p0_3L_2L7)
# Processing: Data/Wenu_PTV70_140_CFilterBVeto.csv
#   -> Added 306 events (event name: Wenu_PTV70_140_CFilterBVeto)
# Processing: Data/WqqZll_sample2000.csv
#   -> Added 2000 events (event name: WqqZll)
# Processing: Data/llvv_sample2000.csv
#   -> Added 2000 events (event name: llvv)
# Processing: Data/Zmumu_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV280_500_CVetoBVeto)
# Processing: Data/Zee_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV140_280_CVetoBVeto)
# Processing: Data/TT_directTT_500_200_sample2000.csv
#   -> Added 2000 events (event name: TT_directTT_500_200)
# Processing: Data/Ztautau_PTV0_70_CVetoBVeto.csv
#   -> Added 30 events (event name: Ztautau_PTV0_70_CVetoBVeto)
# Processing: Data/ttbar_lep_sample10000.csv
#   -> Added 10000 events (event name: ttbar_lep)
# Processing: Data/Zmumu_PTV70_140_CVetoBVeto.csv
#   -> Added 67 events (event name: Zmumu_PTV70_140_CVetoBVeto)
# Processing: Data/Ztautau_PTV0_70_CFilterBVeto.csv
#   -> Added 16 events (event name: Ztautau_PTV0_70_CFilterBVeto)
# Processing: Data/Zee_sample2000.csv
#   -> Added 2000 events (event name: Zee)
# Processing: Data/Zmumu_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV1000_E_CMS)
# Processing: Data/Wminustaunu.csv
#   -> Added 962 events (event name: Wminustaunu)
# Processing: Data/Zmumu_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV140_280_BFilter)
# Processing: Data/Wmunu_PTV70_140_BFilter.csv
#   -> Added 265 events (event name: Wmunu_PTV70_140_BFilter)
# Processing: Data/Wmunu_PTV500_1000_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV500_1000)
# Processing: Data/Wplusmunu_sample2000.csv
#   -> Added 2000 events (event name: Wplusmunu)
# Processing: Data/GG_ttn1_1400_5000_1_sample2000.csv
#   -> Added 2000 events (event name: GG_ttn1_1400_5000_1)
# Processing: Data/lllv_sample2000.csv
#   -> Added 2000 events (event name: lllv)
# Processing: Data/single_antitop_schan.csv
#   -> Added 2068 events (event name: single_antitop_schan)
# Processing: Data/single_top_tchan_sample10000.csv
#   -> Added 10000 events (event name: single_top_tchan)
# Processing: Data/Wmunu_PTV0_70_CVetoBVeto.csv
#   -> Added 102 events (event name: Wmunu_PTV0_70_CVetoBVeto)
# Processing: Data/Zee_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV280_500_CVetoBVeto)
# Processing: Data/ZPrime1000_tt.csv
#   -> Added 29427 events (event name: ZPrime1000_tt)
# Processing: Data/ZqqZll_sample2000.csv
#   -> Added 2000 events (event name: ZqqZll)
# Processing: Data/Wminusenu_sample2000.csv
#   -> Added 2000 events (event name: Wminusenu)
# Processing: Data/lvvv_sample2000.csv
#   -> Added 2000 events (event name: lvvv)
# Processing: Data/ZPrime500_tt.csv
#   -> Added 1446 events (event name: ZPrime500_tt)
# Processing: Data/Zmumu_PTV0_70_CFilterBVeto.csv
#   -> Added 39 events (event name: Zmumu_PTV0_70_CFilterBVeto)
# Processing: Data/Wenu_PTV0_70_CFilterBVeto.csv
#   -> Added 112 events (event name: Wenu_PTV0_70_CFilterBVeto)
# Processing: Data/Ztautau_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV280_500_CFilterBVeto)
# Processing: Data/Zee_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV280_500_CFilterBVeto)
# Processing: Data/Wtaunu_PTV70_140_CFilterBVeto.csv
#   -> Added 18 events (event name: Wtaunu_PTV70_140_CFilterBVeto)
# Processing: Data/Zee_PTV140_280_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV140_280_CFilterBVeto)
# Processing: Data/GG_ttn1_1200_5000_1_sample2000.csv
#   -> Added 2000 events (event name: GG_ttn1_1200_5000_1)
# Processing: Data/WplvWmqq_sample2000.csv
#   -> Added 2000 events (event name: WplvWmqq)
# Processing: Data/Zmumu_PTV0_70_CVetoBVeto.csv
#   -> Added 35 events (event name: Zmumu_PTV0_70_CVetoBVeto)
# Processing: Data/Wenu_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV1000_E_CMS)
# Processing: Data/ZPrime1500_tt.csv
#   -> Added 36985 events (event name: ZPrime1500_tt)
# Processing: Data/Zmumu_PTV0_70_BFilter.csv
#   -> Added 88 events (event name: Zmumu_PTV0_70_BFilter)
# Processing: Data/ZPrime2000_tt.csv
#   -> Added 35353 events (event name: ZPrime2000_tt)
# Processing: Data/Ztautau_PTV70_140_CFilterBVeto.csv
#   -> Added 23 events (event name: Ztautau_PTV70_140_CFilterBVeto)
# Processing: Data/Wmunu_PTV0_70_BFilter.csv
#   -> Added 107 events (event name: Wmunu_PTV0_70_BFilter)
# Processing: Data/Zmumu_sample2000.csv
#   -> Added 2000 events (event name: Zmumu)
# Processing: Data/ZPrime2250_tt.csv
#   -> Added 33813 events (event name: ZPrime2250_tt)
# Processing: Data/Zee_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV280_500_BFilter)
# Processing: Data/Wenu_PTV70_140_CVetoBVeto.csv
#   -> Added 511 events (event name: Wenu_PTV70_140_CVetoBVeto)
# Processing: Data/Ztautau_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV1000_E_CMS)
# Processing: Data/Wtaunu_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV280_500_CFilterBVeto)
# Processing: Data/GG_ttn1_1200_5000_600_sample2000.csv
#   -> Added 2000 events (event name: GG_ttn1_1200_5000_600)
# Processing: Data/Wenu_PTV70_140_BFilter.csv
#   -> Added 233 events (event name: Wenu_PTV70_140_BFilter)
# Processing: Data/Wtaunu_PTV0_70_CVetoBVeto.csv
#   -> Added 7 events (event name: Wtaunu_PTV0_70_CVetoBVeto)
# Processing: Data/Wtaunu_PTV1000_E_CMS_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV1000_E_CMS)
# Processing: Data/Wtaunu_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV280_500_BFilter)
# Processing: Data/Ztautau_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV280_500_BFilter)
# Processing: Data/ZPrime1250_tt.csv
#   -> Added 35493 events (event name: ZPrime1250_tt)
# Processing: Data/Zee_PTV140_280_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Zee_PTV140_280_BFilter)
# Processing: Data/ZPrime750_tt.csv
#   -> Added 15300 events (event name: ZPrime750_tt)
# Processing: Data/Wtaunu_PTV500_1000_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV500_1000)
# Processing: Data/Wtaunu_PTV0_70_CFilterBVeto.csv
#   -> Added 5 events (event name: Wtaunu_PTV0_70_CFilterBVeto)
# Processing: Data/ZPrime2500_tt.csv
#   -> Added 31832 events (event name: ZPrime2500_tt)
# Processing: Data/Ztautau_PTV500_1000_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV500_1000)
# Processing: Data/Wplustaunu.csv
#   -> Added 1392 events (event name: Wplustaunu)
# Processing: Data/Wenu_PTV280_500_BFilter_sample2000.csv
#   -> Added 2000 events (event name: Wenu_PTV280_500_BFilter)
# Processing: Data/Ztautau_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Ztautau_PTV140_280_CVetoBVeto)
# Processing: Data/Wmunu_PTV280_500_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wmunu_PTV280_500_CVetoBVeto)
# Processing: Data/Wtaunu_PTV140_280_CVetoBVeto_sample2000.csv
#   -> Added 2000 events (event name: Wtaunu_PTV140_280_CVetoBVeto)
# Processing: Data/Wmunu_PTV70_140_CVetoBVeto.csv
#   -> Added 144 events (event name: Wmunu_PTV70_140_CVetoBVeto)
# Processing: Data/ZPrime1750_tt.csv
#   -> Added 36920 events (event name: ZPrime1750_tt)
# Processing: Data/Zmumu_PTV280_500_CFilterBVeto_sample2000.csv
#   -> Added 2000 events (event name: Zmumu_PTV280_500_CFilterBVeto)
#
# Combined dataset: 527503 total events
# Columns: ['event', 'runNumber', 'eventNumber', 'channelNumber', 'mcWeight', 'XSection', 'SumWeights', 'scaleFactor_PILEUP', 'scaleFactor_ELE', 'scaleFactor_MUON', 'scaleFactor_PHOTON', 'scaleFactor_TAU', 'scaleFactor_BTAG', 'scaleFactor_LepTRIGGER', 'scaleFactor_PhotonTRIGGER', 'trigE', 'trigM', 'trigP', 'lep_n', 'lep_truthMatched', 'lep_trigMatched', 'lep_pt', 'lep_eta', 'lep_phi', 'lep_E', 'lep_z0', 'lep_charge', 'lep_type', 'lep_isTightID', 'lep_ptcone30', 'lep_etcone20', 'lep_trackd0pvunbiased', 'lep_tracksigd0pvunbiased', 'met_et', 'met_phi', 'jet_n', 'jet_pt', 'jet_eta', 'jet_phi', 'jet_E', 'jet_jvt', 'jet_trueflav', 'jet_truthMatched', 'jet_MV2c10', 'photon_n', 'photon_truthMatched', 'photon_trigMatched', 'photon_pt', 'photon_eta', 'photon_phi', 'photon_E', 'photon_isTightID', 'photon_ptcone30', 'photon_etcone20', 'photon_convType', 'largeRjet_n', 'largeRjet_pt', 'largeRjet_eta', 'largeRjet_phi', 'largeRjet_E', 'largeRjet_m', 'largeRjet_truthMatched', 'largeRjet_D2', 'largeRjet_tau32', 'tau_n', 'tau_pt', 'tau_eta', 'tau_phi', 'tau_E', 'tau_charge', 'tau_isTightID', 'tau_truthMatched', 'tau_trigMatched', 'tau_nTracks', 'tau_BDTid', 'ditau_m', 'lep_pt_syst', 'met_et_syst', 'jet_pt_syst', 'photon_pt_syst', 'largeRjet_pt_syst', 'tau_pt_syst', 'full_event_name']
#
# First few rows:
#    event  runNumber  eventNumber  channelNumber  jet_n  lep_n  \
# 0     68     284500         4965         364179      3      1
# 1     86     284500         6584         364179      5      1
# 2    217     284500         4094         364179      2      1
# 3    484     284500         3299         364179      1      1
# 4   1210     284500       173767         364179      5      1
#
#               full_event_name
# 0  Wenu_PTV280_500_CVetoBVeto
# 1  Wenu_PTV280_500_CVetoBVeto
# 2  Wenu_PTV280_500_CVetoBVeto
# 3  Wenu_PTV280_500_CVetoBVeto
# 4  Wenu_PTV280_500_CVetoBVeto
#
# Final dataset shape: (527503, 83)
#
# Target extraction complete:
# Unique particle types: ['C1N2' 'GG' 'VV' 'W' 'Z' 'ZPrime' 'Zprime2000' 'Zprime750' 'top']
# Number of classes: 9
#
# Particle type distribution:
# event_type
# Unknown       242649
# Z              65251
# top            62068
# W              50445
# Zprime2000     35353
# ZPrime         29427
# Zprime750      15300
# VV             14000
# GG              8000
# C1N2            5010
# Name: count, dtype: int64
# Cleaned 56 list columns in DataFrame
# Event type to target mapping:
#         event_type  numeric_target
# 16011         C1N2               0
# 146641          GG               1
# 48884           VV               2
# 0                W               3
# 6000             Z               4
# 218220      ZPrime               5
# 304370  Zprime2000               6
# 427910   Zprime750               7
# 6011           top               8
# columns = Index(['event', 'runNumber', 'eventNumber', 'channelNumber', 'mcWeight',
#        'XSection', 'SumWeights', 'scaleFactor_PILEUP', 'scaleFactor_ELE',
#        'scaleFactor_MUON', 'scaleFactor_PHOTON', 'scaleFactor_TAU',
#        'scaleFactor_BTAG', 'scaleFactor_LepTRIGGER',
#        'scaleFactor_PhotonTRIGGER', 'trigE', 'trigM', 'trigP', 'lep_n',
#        'lep_truthMatched', 'lep_trigMatched', 'lep_pt', 'lep_eta', 'lep_phi',
#        'lep_E', 'lep_z0', 'lep_charge', 'lep_type', 'lep_isTightID',
#        'lep_ptcone30', 'lep_etcone20', 'lep_trackd0pvunbiased',
#        'lep_tracksigd0pvunbiased', 'met_et', 'met_phi', 'jet_n', 'jet_pt',
#        'jet_eta', 'jet_phi', 'jet_E', 'jet_jvt', 'jet_trueflav',
#        'jet_truthMatched', 'jet_MV2c10', 'photon_n', 'photon_truthMatched',
#        'photon_trigMatched', 'photon_pt', 'photon_eta', 'photon_phi',
#        'photon_E', 'photon_isTightID', 'photon_ptcone30', 'photon_etcone20',
#        'photon_convType', 'largeRjet_n', 'largeRjet_pt', 'largeRjet_eta',
#        'largeRjet_phi', 'largeRjet_E', 'largeRjet_m', 'largeRjet_truthMatched',
#        'largeRjet_D2', 'largeRjet_tau32', 'tau_n', 'tau_pt', 'tau_eta',
#        'tau_phi', 'tau_E', 'tau_charge', 'tau_isTightID', 'tau_truthMatched',
#        'tau_trigMatched', 'tau_nTracks', 'tau_BDTid', 'ditau_m', 'lep_pt_syst',
#        'met_et_syst', 'jet_pt_syst', 'photon_pt_syst', 'largeRjet_pt_syst',
#        'tau_pt_syst', 'full_event_name', 'onehot_target', 'numeric_target',
#        'event_type'],
#       dtype='object')
# List columns: 41
# Scalar columns: 11
# Extracting 5 elements from each list column
# Shape after feature extraction: (284854, 216)
# Column trigP is all zeros, will drop it.
# Column photon_n is all zeros, will drop it.
# Column tau_n is all zeros, will drop it.
# Column ditau_m is all zeros, will drop it.
# Column photon_pt_first is all zeros, will drop it.
# Column photon_pt_second is all zeros, will drop it.
# Column photon_pt_third is all NaN, will drop it.
# Column photon_pt_fourth is all NaN, will drop it.
# Column photon_pt_fifth is all NaN, will drop it.
# Column photon_eta_first is all zeros, will drop it.
# Column photon_eta_second is all zeros, will drop it.
# Column photon_eta_third is all NaN, will drop it.
# Column photon_eta_fourth is all NaN, will drop it.
# Column photon_eta_fifth is all NaN, will drop it.
# Column photon_phi_first is all zeros, will drop it.
# Column photon_phi_second is all zeros, will drop it.
# Column photon_phi_third is all NaN, will drop it.
# Column photon_phi_fourth is all NaN, will drop it.
# Column photon_phi_fifth is all NaN, will drop it.
# Column photon_E_first is all zeros, will drop it.
# Column photon_E_second is all zeros, will drop it.
# Column photon_E_third is all NaN, will drop it.
# Column photon_E_fourth is all NaN, will drop it.
# Column photon_E_fifth is all NaN, will drop it.
# Column photon_isTightID_first is all zeros, will drop it.
# Column photon_isTightID_second is all zeros, will drop it.
# Column photon_isTightID_third is all NaN, will drop it.
# Column photon_isTightID_fourth is all NaN, will drop it.
# Column photon_isTightID_fifth is all NaN, will drop it.
# Column photon_ptcone30_first is all zeros, will drop it.
# Column photon_ptcone30_second is all zeros, will drop it.
# Column photon_ptcone30_third is all NaN, will drop it.
# Column photon_ptcone30_fourth is all NaN, will drop it.
# Column photon_ptcone30_fifth is all NaN, will drop it.
# Column photon_etcone20_first is all zeros, will drop it.
# Column photon_etcone20_second is all zeros, will drop it.
# Column photon_etcone20_third is all NaN, will drop it.
# Column photon_etcone20_fourth is all NaN, will drop it.
# Column photon_etcone20_fifth is all NaN, will drop it.
# Column photon_convType_first is all zeros, will drop it.
# Column photon_convType_second is all zeros, will drop it.
# Column photon_convType_third is all NaN, will drop it.
# Column photon_convType_fourth is all NaN, will drop it.
# Column photon_convType_fifth is all NaN, will drop it.
# Column tau_pt_first is all zeros, will drop it.
# Column tau_pt_second is all zeros, will drop it.
# Column tau_pt_third is all NaN, will drop it.
# Column tau_pt_fourth is all NaN, will drop it.
# Column tau_pt_fifth is all NaN, will drop it.
# Column tau_eta_first is all zeros, will drop it.
# Column tau_eta_second is all zeros, will drop it.
# Column tau_eta_third is all NaN, will drop it.
# Column tau_eta_fourth is all NaN, will drop it.
# Column tau_eta_fifth is all NaN, will drop it.
# Column tau_phi_first is all zeros, will drop it.
# Column tau_phi_second is all zeros, will drop it.
# Column tau_phi_third is all NaN, will drop it.
# Column tau_phi_fourth is all NaN, will drop it.
# Column tau_phi_fifth is all NaN, will drop it.
# Column tau_E_first is all zeros, will drop it.
# Column tau_E_second is all zeros, will drop it.
# Column tau_E_third is all NaN, will drop it.
# Column tau_E_fourth is all NaN, will drop it.
# Column tau_E_fifth is all NaN, will drop it.
# Column tau_charge_first is all zeros, will drop it.
# Column tau_charge_second is all zeros, will drop it.
# Column tau_charge_third is all NaN, will drop it.
# Column tau_charge_fourth is all NaN, will drop it.
# Column tau_charge_fifth is all NaN, will drop it.
# Column tau_isTightID_first is all zeros, will drop it.
# Column tau_isTightID_second is all zeros, will drop it.
# Column tau_isTightID_third is all NaN, will drop it.
# Column tau_isTightID_fourth is all NaN, will drop it.
# Column tau_isTightID_fifth is all NaN, will drop it.
# Column tau_nTracks_first is all zeros, will drop it.
# Column tau_nTracks_second is all zeros, will drop it.
# Column tau_nTracks_third is all NaN, will drop it.
# Column tau_nTracks_fourth is all NaN, will drop it.
# Column tau_nTracks_fifth is all NaN, will drop it.
# Column tau_BDTid_first is all zeros, will drop it.
# Column tau_BDTid_second is all zeros, will drop it.
# Column tau_BDTid_third is all NaN, will drop it.
# Column tau_BDTid_fourth is all NaN, will drop it.
# Column tau_BDTid_fifth is all NaN, will drop it.
# Dropped 84 NaN columns
# Final shape: (284854, 132)
# Columns with '_first':
# ['lep_pt_first', 'lep_eta_first', 'lep_phi_first', 'lep_E_first', 'lep_z0_first', 'lep_charge_first', 'lep_type_first', 'lep_isTightID_first', 'lep_ptcone30_first', 'lep_etcone20_first', 'lep_trackd0pvunbiased_first', 'lep_tracksigd0pvunbiased_first', 'jet_pt_first', 'jet_eta_first', 'jet_phi_first', 'jet_E_first', 'jet_jvt_first', 'jet_MV2c10_first', 'largeRjet_pt_first', 'largeRjet_eta_first', 'largeRjet_phi_first', 'largeRjet_E_first', 'largeRjet_m_first', 'largeRjet_D2_first', 'largeRjet_tau32_first']
#
# Creating TOTAL columns:
#   lep_pt_total from 5 columns: ['lep_pt_first', 'lep_pt_second', 'lep_pt_third', 'lep_pt_fourth', 'lep_pt_fifth']
#   lep_E_total from 5 columns: ['lep_E_first', 'lep_E_second', 'lep_E_third', 'lep_E_fourth', 'lep_E_fifth']
#   lep_charge_total from 5 columns: ['lep_charge_first', 'lep_charge_second', 'lep_charge_third', 'lep_charge_fourth', 'lep_charge_fifth']
#   lep_ptcone30_total from 5 columns: ['lep_ptcone30_first', 'lep_ptcone30_second', 'lep_ptcone30_third', 'lep_ptcone30_fourth', 'lep_ptcone30_fifth']
#   lep_etcone20_total from 5 columns: ['lep_etcone20_first', 'lep_etcone20_second', 'lep_etcone20_third', 'lep_etcone20_fourth', 'lep_etcone20_fifth']
#   jet_pt_total from 5 columns: ['jet_pt_first', 'jet_pt_second', 'jet_pt_third', 'jet_pt_fourth', 'jet_pt_fifth']
#   jet_E_total from 5 columns: ['jet_E_first', 'jet_E_second', 'jet_E_third', 'jet_E_fourth', 'jet_E_fifth']
#   largeRjet_pt_total from 5 columns: ['largeRjet_pt_first', 'largeRjet_pt_second', 'largeRjet_pt_third', 'largeRjet_pt_fourth', 'largeRjet_pt_fifth']
#   largeRjet_E_total from 5 columns: ['largeRjet_E_first', 'largeRjet_E_second', 'largeRjet_E_third', 'largeRjet_E_fourth', 'largeRjet_E_fifth']
#   largeRjet_m_total from 5 columns: ['largeRjet_m_first', 'largeRjet_m_second', 'largeRjet_m_third', 'largeRjet_m_fourth', 'largeRjet_m_fifth']
#
# Creating MEAN columns:
#   lep_eta_mean from 5 columns: ['lep_eta_first', 'lep_eta_second', 'lep_eta_third', 'lep_eta_fourth', 'lep_eta_fifth']
#   lep_phi_mean from 5 columns: ['lep_phi_first', 'lep_phi_second', 'lep_phi_third', 'lep_phi_fourth', 'lep_phi_fifth']
#   lep_z0_mean from 5 columns: ['lep_z0_first', 'lep_z0_second', 'lep_z0_third', 'lep_z0_fourth', 'lep_z0_fifth']
#   jet_eta_mean from 5 columns: ['jet_eta_first', 'jet_eta_second', 'jet_eta_third', 'jet_eta_fourth', 'jet_eta_fifth']
#   jet_phi_mean from 5 columns: ['jet_phi_first', 'jet_phi_second', 'jet_phi_third', 'jet_phi_fourth', 'jet_phi_fifth']
#   largeRjet_eta_mean from 5 columns: ['largeRjet_eta_first', 'largeRjet_eta_second', 'largeRjet_eta_third', 'largeRjet_eta_fourth', 'largeRjet_eta_fifth']
#   largeRjet_phi_mean from 5 columns: ['largeRjet_phi_first', 'largeRjet_phi_second', 'largeRjet_phi_third', 'largeRjet_phi_fourth', 'largeRjet_phi_fifth']
#
# Shape after adding totals and means: (284854, 149)
# Added 10 total columns and 7 mean columns
# Total columns: ['lep_pt_total', 'lep_E_total', 'lep_charge_total', 'lep_ptcone30_total', 'lep_etcone20_total', 'jet_pt_total', 'jet_E_total', 'largeRjet_pt_total', 'largeRjet_E_total', 'largeRjet_m_total']
# Mean columns: ['lep_eta_mean', 'lep_phi_mean', 'lep_z0_mean', 'jet_eta_mean', 'jet_phi_mean', 'largeRjet_eta_mean', 'largeRjet_phi_mean']
# 75 cols are more than 10% NaN out of 149
# NaN fractions per column:
#   lep_pt_third: 98.6%
#   lep_pt_fourth: 100.0%
#   lep_pt_fifth: 100.0%
#   lep_eta_third: 98.6%
#   lep_eta_fourth: 100.0%
#   lep_eta_fifth: 100.0%
#   lep_phi_third: 98.6%
#   lep_phi_fourth: 100.0%
#   lep_phi_fifth: 100.0%
#   lep_E_third: 98.6%
#   lep_E_fourth: 100.0%
#   lep_E_fifth: 100.0%
#   lep_z0_third: 98.6%
#   lep_z0_fourth: 100.0%
#   lep_z0_fifth: 100.0%
#   lep_charge_third: 98.6%
#   lep_charge_fourth: 100.0%
#   lep_charge_fifth: 100.0%
#   lep_type_third: 98.6%
#   lep_type_fourth: 100.0%
#   lep_type_fifth: 100.0%
#   lep_isTightID_third: 98.6%
#   lep_isTightID_fourth: 100.0%
#   lep_isTightID_fifth: 100.0%
#   lep_ptcone30_third: 98.6%
#   lep_ptcone30_fourth: 100.0%
#   lep_ptcone30_fifth: 100.0%
#   lep_etcone20_third: 98.6%
#   lep_etcone20_fourth: 100.0%
#   lep_etcone20_fifth: 100.0%
#   lep_trackd0pvunbiased_third: 98.6%
#   lep_trackd0pvunbiased_fourth: 100.0%
#   lep_trackd0pvunbiased_fifth: 100.0%
#   lep_tracksigd0pvunbiased_third: 98.6%
#   lep_tracksigd0pvunbiased_fourth: 100.0%
#   lep_tracksigd0pvunbiased_fifth: 100.0%
#   jet_pt_third: 28.0%
#   jet_pt_fourth: 47.7%
#   jet_pt_fifth: 66.4%
#   jet_eta_third: 28.0%
#   jet_eta_fourth: 47.7%
#   jet_eta_fifth: 66.4%
#   jet_phi_third: 28.0%
#   jet_phi_fourth: 47.7%
#   jet_phi_fifth: 66.4%
#   jet_E_third: 28.0%
#   jet_E_fourth: 47.7%
#   jet_E_fifth: 66.4%
#   jet_jvt_third: 28.0%
#   jet_jvt_fourth: 47.7%
#   jet_jvt_fifth: 66.4%
#   jet_MV2c10_third: 28.0%
#   jet_MV2c10_fourth: 47.7%
#   jet_MV2c10_fifth: 66.4%
#   largeRjet_pt_third: 97.5%
#   largeRjet_pt_fourth: 99.8%
#   largeRjet_pt_fifth: 100.0%
#   largeRjet_eta_third: 97.5%
#   largeRjet_eta_fourth: 99.8%
#   largeRjet_eta_fifth: 100.0%
#   largeRjet_phi_third: 97.5%
#   largeRjet_phi_fourth: 99.8%
#   largeRjet_phi_fifth: 100.0%
#   largeRjet_E_third: 97.5%
#   largeRjet_E_fourth: 99.8%
#   largeRjet_E_fifth: 100.0%
#   largeRjet_m_third: 97.5%
#   largeRjet_m_fourth: 99.8%
#   largeRjet_m_fifth: 100.0%
#   largeRjet_D2_third: 97.5%
#   largeRjet_D2_fourth: 99.8%
#   largeRjet_D2_fifth: 100.0%
#   largeRjet_tau32_third: 97.5%
#   largeRjet_tau32_fourth: 99.8%
#   largeRjet_tau32_fifth: 100.0%
# Columns remaining after dropping high-NaN columns: 74
# Columns with NaN values (0 out of 74):
# No columns have NaN values! YIPPIEEE!!
# Shape before dropping NaN rows: (284854, 74)
# Shape after dropping NaN rows: (284854, 74)
# Dropped 0 rows with NaN values
# Target dataframe shape: (284854, 86)
# Features and targets are aligned: True

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get class distribution data
a, c = np.unique(df['numeric_target'], return_counts=True)
event_names = np.unique(df.event_type)
event_names = [event if event[:2] != 'Zp' else "Z'" + event.split('e')[1] for event in event_names]

# Create the plot with better styling
plt.figure(figsize=(12, 8), dpi=300)

# Create color palette
colors = plt.cm.Set3(np.linspace(0, 1, len(event_names)))

# Create bar plot
bars = plt.bar(event_names, c, alpha=0.8, edgecolor='black', linewidth=0.8)

# Add value labels on top of bars
for bar, count in zip(bars, c):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max(c)*0.01,
             f'{count:,}', ha='center', va='bottom', fontweight='bold', fontsize=10)

# Formatting
plt.xlabel('Event Type', fontsize=14, fontweight='bold')
plt.ylabel('Number of Events', fontsize=14, fontweight='bold')
plt.title('Class Distribution in Dataset', fontsize=16, fontweight='bold', pad=20)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add grid for better readability
plt.grid(True, alpha=0.3, axis='y', linestyle='-', linewidth=0.5)
plt.gca().set_axisbelow(True)

# Format y-axis to show numbers with commas
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x):,}'))

# Add summary statistics
total_events = sum(c)
max_class = max(c)
min_class = min(c)
imbalance_ratio = max_class / min_class

# Add text box with statistics
textstr = f'''Dataset Statistics:
• Total events: {total_events:,}
• Classes: {len(event_names)}'''

props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
plt.text(0.02, 0.98, textstr, transform=plt.gca().transAxes, fontsize=11,
         verticalalignment='top', bbox=props, family='monospace')

# Tight layout to prevent label cutoff
plt.tight_layout()
plt.show()

# Print class distribution summary
print("Class Distribution Summary:")
for name, count in zip(event_names, c):
    percentage = (count / total_events) * 100
    print(f"{name:15}: {count:6,} events ({percentage:5.1f}%)")
# Out:
# Class Distribution Summary:
# C1N2           :  5,010 events (  1.8%)
# GG             :  8,000 events (  2.8%)
# VV             : 14,000 events (  4.9%)
# W              : 50,445 events ( 17.7%)
# Z              : 65,251 events ( 22.9%)
# ZPrime         : 29,427 events ( 10.3%)
# Z'2000         : 35,353 events ( 12.4%)
# Z'750          : 15,300 events (  5.4%)
# top            : 62,068 events ( 21.8%)

# %% [markdown]
# ## CORR optimization

# %%
from sklearn.preprocessing import QuantileTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping


corr_list = [0.99, 0.95, 0.90, 0.85]  # List of correlation thresholds to check
DNN_Histories = ['corr', 'History']

for c in corr_list:
    print(f"Checking correlation threshold: {c}")
    
    
    print(f'number of initial features: {len(df_extracted.columns)}')
    corr = df_extracted.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

    # Find features with correlation greater than 0.7
    to_drop = [column for column in upper.columns if any(upper[column] > c)]
    # print('cols to drop:' + str(to_drop))
    # Drop features 
    df_new = df_extracted.copy()  # Create a copy to avoid modifying original df_extracted
    df_new.drop(to_drop, axis=1, inplace=True)

    corr2 = df_new.corr().abs()
    print(f'number of final features:{len(df_new.columns)}')


    # Scaling
    qt = QuantileTransformer(output_distribution='uniform', n_quantiles=1000) #TODO: try uniform distribution
    X_scaled = qt.fit_transform(df_new)

    # Train Test Split
    from sklearn.model_selection import train_test_split
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, df['numeric_target'], test_size=0.2, random_state=42, stratify=df['numeric_target'])

    num_classes = len(df['numeric_target'].unique())


    # Define the model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    ES = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[ES])

    DNN_Histories.append([c, history])
# Out:
# 2025-07-10 00:29:38.712537: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-10 00:29:38.885559: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-10 00:29:39.056035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752100179.187078   17107 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752100179.224195   17107 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752100179.540968   17107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752100179.541001   17107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752100179.541005   17107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752100179.541008   17107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-10 00:29:39.571657: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Checking correlation threshold: 0.99
# number of initial features: 74
# number of final features:74
# 2025-07-10 00:29:54.960641: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.5342 - loss: 1.1141 - val_accuracy: 0.5994 - val_loss: 0.9358
# Epoch 2/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.5928 - loss: 0.9682 - val_accuracy: 0.6001 - val_loss: 0.9236
# Epoch 3/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6000 - loss: 0.9475 - val_accuracy: 0.6092 - val_loss: 0.9134
# Epoch 4/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6086 - loss: 0.9335 - val_accuracy: 0.6047 - val_loss: 0.9134
# Epoch 5/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6095 - loss: 0.9254 - val_accuracy: 0.6161 - val_loss: 0.9052
# Epoch 6/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6164 - loss: 0.9192 - val_accuracy: 0.6153 - val_loss: 0.9013
# Epoch 7/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6145 - loss: 0.9183 - val_accuracy: 0.6164 - val_loss: 0.8875
# Epoch 8/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6221 - loss: 0.9094 - val_accuracy: 0.6193 - val_loss: 0.8967
# Epoch 9/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6189 - loss: 0.9050 - val_accuracy: 0.6206 - val_loss: 0.8916
# Epoch 10/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6249 - loss: 0.8982 - val_accuracy: 0.6266 - val_loss: 0.8802
# Epoch 11/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6229 - loss: 0.9036 - val_accuracy: 0.6210 - val_loss: 0.8938
# Epoch 12/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6279 - loss: 0.8920 - val_accuracy: 0.6296 - val_loss: 0.8813
# Epoch 13/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6261 - loss: 0.8910 - val_accuracy: 0.6256 - val_loss: 0.8802
# Epoch 14/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6263 - loss: 0.8912 - val_accuracy: 0.6293 - val_loss: 0.8738
# Epoch 15/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6295 - loss: 0.8923 - val_accuracy: 0.6243 - val_loss: 0.8852
# Epoch 16/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6312 - loss: 0.8859 - val_accuracy: 0.6249 - val_loss: 0.8828
# Epoch 17/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6274 - loss: 0.8913 - val_accuracy: 0.6336 - val_loss: 0.8714
# Epoch 18/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6329 - loss: 0.8815 - val_accuracy: 0.6307 - val_loss: 0.8753
# Epoch 19/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6326 - loss: 0.8819 - val_accuracy: 0.6317 - val_loss: 0.8714
# Epoch 20/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6313 - loss: 0.8801 - val_accuracy: 0.6321 - val_loss: 0.8700
# Epoch 21/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6315 - loss: 0.8772 - val_accuracy: 0.6355 - val_loss: 0.8621
# Epoch 22/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6324 - loss: 0.8760 - val_accuracy: 0.6368 - val_loss: 0.8660
# Epoch 23/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6363 - loss: 0.8752 - val_accuracy: 0.6340 - val_loss: 0.8739
# Epoch 24/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6336 - loss: 0.8764 - val_accuracy: 0.6345 - val_loss: 0.8692
# Epoch 25/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6351 - loss: 0.8734 - val_accuracy: 0.6322 - val_loss: 0.8756
# Epoch 26/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6381 - loss: 0.8694 - val_accuracy: 0.6286 - val_loss: 0.8806
# Epoch 27/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6345 - loss: 0.8709 - val_accuracy: 0.6277 - val_loss: 0.8815
# Epoch 28/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6381 - loss: 0.8682 - val_accuracy: 0.6363 - val_loss: 0.8629
# Epoch 29/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6349 - loss: 0.8705 - val_accuracy: 0.6343 - val_loss: 0.8704
# Epoch 30/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6380 - loss: 0.8664 - val_accuracy: 0.6326 - val_loss: 0.8635
# Epoch 31/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6348 - loss: 0.8690 - val_accuracy: 0.6377 - val_loss: 0.8720
# Epoch 32/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6370 - loss: 0.8685 - val_accuracy: 0.6340 - val_loss: 0.8712
# Epoch 33/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6374 - loss: 0.8685 - val_accuracy: 0.6364 - val_loss: 0.8658
# Epoch 34/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6392 - loss: 0.8660 - val_accuracy: 0.6379 - val_loss: 0.8599
# Epoch 35/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6368 - loss: 0.8674 - val_accuracy: 0.6372 - val_loss: 0.8668
# Epoch 36/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6393 - loss: 0.8675 - val_accuracy: 0.6373 - val_loss: 0.8604
# Epoch 37/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6408 - loss: 0.8614 - val_accuracy: 0.6400 - val_loss: 0.8613
# Epoch 38/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6369 - loss: 0.8667 - val_accuracy: 0.6355 - val_loss: 0.8682
# Epoch 39/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6396 - loss: 0.8634 - val_accuracy: 0.6397 - val_loss: 0.8608
# Epoch 40/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6370 - loss: 0.8651 - val_accuracy: 0.6385 - val_loss: 0.8594
# Epoch 41/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6405 - loss: 0.8586 - val_accuracy: 0.6379 - val_loss: 0.8658
# Epoch 42/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6383 - loss: 0.8647 - val_accuracy: 0.6390 - val_loss: 0.8562
# Epoch 43/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6407 - loss: 0.8606 - val_accuracy: 0.6391 - val_loss: 0.8587
# Epoch 44/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6414 - loss: 0.8631 - val_accuracy: 0.6327 - val_loss: 0.8632
# Epoch 45/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6375 - loss: 0.8669 - val_accuracy: 0.6378 - val_loss: 0.8630
# Epoch 46/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6406 - loss: 0.8570 - val_accuracy: 0.6415 - val_loss: 0.8580
# Epoch 47/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6413 - loss: 0.8600 - val_accuracy: 0.6272 - val_loss: 0.8688
# Epoch 48/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6419 - loss: 0.8589 - val_accuracy: 0.6405 - val_loss: 0.8600
# Epoch 49/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6377 - loss: 0.8639 - val_accuracy: 0.6372 - val_loss: 0.8615
# Epoch 50/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6406 - loss: 0.8613 - val_accuracy: 0.6390 - val_loss: 0.8602
# Epoch 51/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6393 - loss: 0.8596 - val_accuracy: 0.6373 - val_loss: 0.8605
# Epoch 52/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6427 - loss: 0.8595 - val_accuracy: 0.6408 - val_loss: 0.8579
# Epoch 53/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6446 - loss: 0.8585 - val_accuracy: 0.6377 - val_loss: 0.8630
# Epoch 54/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6396 - loss: 0.8585 - val_accuracy: 0.6355 - val_loss: 0.8638
# Epoch 55/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6442 - loss: 0.8519 - val_accuracy: 0.6390 - val_loss: 0.8616
# Epoch 56/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6420 - loss: 0.8565 - val_accuracy: 0.6401 - val_loss: 0.8611
# Epoch 57/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6434 - loss: 0.8543 - val_accuracy: 0.6397 - val_loss: 0.8590
# Epoch 58/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6452 - loss: 0.8555 - val_accuracy: 0.6431 - val_loss: 0.8561
# Epoch 59/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6422 - loss: 0.8504 - val_accuracy: 0.6400 - val_loss: 0.8606
# Epoch 60/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6456 - loss: 0.8508 - val_accuracy: 0.6414 - val_loss: 0.8590
# Epoch 61/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6422 - loss: 0.8546 - val_accuracy: 0.6380 - val_loss: 0.8580
# Epoch 62/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6444 - loss: 0.8570 - val_accuracy: 0.6406 - val_loss: 0.8569
# Epoch 63/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6414 - loss: 0.8553 - val_accuracy: 0.6420 - val_loss: 0.8627
# Epoch 64/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6461 - loss: 0.8523 - val_accuracy: 0.6363 - val_loss: 0.8643
# Epoch 65/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6426 - loss: 0.8544 - val_accuracy: 0.6408 - val_loss: 0.8592
# Epoch 66/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6428 - loss: 0.8559 - val_accuracy: 0.6330 - val_loss: 0.8694
# Epoch 67/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6435 - loss: 0.8558 - val_accuracy: 0.6401 - val_loss: 0.8654
# Epoch 68/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6450 - loss: 0.8540 - val_accuracy: 0.6345 - val_loss: 0.8671
# Epoch 69/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6443 - loss: 0.8534 - val_accuracy: 0.6385 - val_loss: 0.8610
# Epoch 70/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6433 - loss: 0.8577 - val_accuracy: 0.6412 - val_loss: 0.8550
# Epoch 71/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6459 - loss: 0.8532 - val_accuracy: 0.6426 - val_loss: 0.8530
# Epoch 72/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6460 - loss: 0.8522 - val_accuracy: 0.6369 - val_loss: 0.8610
# Epoch 73/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6464 - loss: 0.8504 - val_accuracy: 0.6407 - val_loss: 0.8612
# Epoch 74/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6443 - loss: 0.8530 - val_accuracy: 0.6417 - val_loss: 0.8527
# Epoch 75/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6421 - loss: 0.8541 - val_accuracy: 0.6390 - val_loss: 0.8608
# Epoch 76/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6493 - loss: 0.8483 - val_accuracy: 0.6402 - val_loss: 0.8565
# Epoch 77/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6411 - loss: 0.8567 - val_accuracy: 0.6438 - val_loss: 0.8567
# Epoch 78/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6474 - loss: 0.8498 - val_accuracy: 0.6461 - val_loss: 0.8592
# Epoch 79/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6454 - loss: 0.8524 - val_accuracy: 0.6414 - val_loss: 0.8598
# Epoch 80/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6473 - loss: 0.8513 - val_accuracy: 0.6444 - val_loss: 0.8557
# Epoch 81/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6464 - loss: 0.8494 - val_accuracy: 0.6361 - val_loss: 0.8721
# Epoch 82/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6443 - loss: 0.8495 - val_accuracy: 0.6347 - val_loss: 0.8588
# Epoch 83/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6465 - loss: 0.8507 - val_accuracy: 0.6404 - val_loss: 0.8579
# Epoch 84/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6462 - loss: 0.8548 - val_accuracy: 0.6379 - val_loss: 0.8677
# Epoch 85/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6427 - loss: 0.8532 - val_accuracy: 0.6407 - val_loss: 0.8570
# Epoch 86/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6436 - loss: 0.8529 - val_accuracy: 0.6439 - val_loss: 0.8563
# Epoch 87/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6447 - loss: 0.8484 - val_accuracy: 0.6388 - val_loss: 0.8657
# Epoch 88/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6445 - loss: 0.8532 - val_accuracy: 0.6381 - val_loss: 0.8628
# Epoch 89/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6448 - loss: 0.8489 - val_accuracy: 0.6442 - val_loss: 0.8547
# Epoch 90/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6472 - loss: 0.8438 - val_accuracy: 0.6411 - val_loss: 0.8567
# Epoch 91/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6460 - loss: 0.8517 - val_accuracy: 0.6413 - val_loss: 0.8579
# Epoch 92/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6446 - loss: 0.8496 - val_accuracy: 0.6414 - val_loss: 0.8610
# Epoch 93/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6432 - loss: 0.8532 - val_accuracy: 0.6369 - val_loss: 0.8688
# Epoch 94/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6475 - loss: 0.8504 - val_accuracy: 0.6433 - val_loss: 0.8583
# Epoch 95/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6480 - loss: 0.8450 - val_accuracy: 0.6424 - val_loss: 0.8489
# Epoch 96/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6459 - loss: 0.8495 - val_accuracy: 0.6429 - val_loss: 0.8566
# Epoch 97/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6452 - loss: 0.8538 - val_accuracy: 0.6411 - val_loss: 0.8621
# Epoch 98/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6444 - loss: 0.8498 - val_accuracy: 0.6424 - val_loss: 0.8602
# Epoch 99/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6452 - loss: 0.8496 - val_accuracy: 0.6398 - val_loss: 0.8520
# Epoch 100/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6463 - loss: 0.8476 - val_accuracy: 0.6414 - val_loss: 0.8581
# Checking correlation threshold: 0.95
# number of initial features: 74
# number of final features:67
# Epoch 1/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.5380 - loss: 1.1023 - val_accuracy: 0.5806 - val_loss: 0.9623
# Epoch 2/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.5917 - loss: 0.9667 - val_accuracy: 0.6061 - val_loss: 0.9212
# Epoch 3/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6016 - loss: 0.9472 - val_accuracy: 0.6090 - val_loss: 0.9179
# Epoch 4/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6047 - loss: 0.9391 - val_accuracy: 0.6089 - val_loss: 0.9184
# Epoch 5/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6125 - loss: 0.9279 - val_accuracy: 0.6081 - val_loss: 0.9246
# Epoch 6/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6158 - loss: 0.9198 - val_accuracy: 0.6164 - val_loss: 0.8999
# Epoch 7/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6162 - loss: 0.9169 - val_accuracy: 0.6180 - val_loss: 0.8999
# Epoch 8/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6192 - loss: 0.9124 - val_accuracy: 0.6176 - val_loss: 0.8939
# Epoch 9/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6194 - loss: 0.9108 - val_accuracy: 0.6214 - val_loss: 0.9002
# Epoch 10/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6213 - loss: 0.9079 - val_accuracy: 0.6179 - val_loss: 0.9016
# Epoch 11/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6207 - loss: 0.9051 - val_accuracy: 0.6269 - val_loss: 0.8833
# Epoch 12/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6236 - loss: 0.8973 - val_accuracy: 0.6255 - val_loss: 0.8849
# Epoch 13/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6254 - loss: 0.8947 - val_accuracy: 0.6299 - val_loss: 0.8787
# Epoch 14/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6232 - loss: 0.8988 - val_accuracy: 0.6303 - val_loss: 0.8805
# Epoch 15/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6282 - loss: 0.8927 - val_accuracy: 0.6283 - val_loss: 0.8820
# Epoch 16/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6286 - loss: 0.8873 - val_accuracy: 0.6341 - val_loss: 0.8804
# Epoch 17/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6298 - loss: 0.8838 - val_accuracy: 0.6308 - val_loss: 0.8794
# Epoch 18/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6309 - loss: 0.8860 - val_accuracy: 0.6257 - val_loss: 0.8950
# Epoch 19/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6289 - loss: 0.8860 - val_accuracy: 0.6306 - val_loss: 0.8721
# Epoch 20/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6266 - loss: 0.8895 - val_accuracy: 0.6277 - val_loss: 0.8770
# Epoch 21/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6307 - loss: 0.8790 - val_accuracy: 0.6298 - val_loss: 0.8715
# Epoch 22/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6312 - loss: 0.8794 - val_accuracy: 0.6317 - val_loss: 0.8705
# Epoch 23/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6317 - loss: 0.8776 - val_accuracy: 0.6315 - val_loss: 0.8688
# Epoch 24/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6353 - loss: 0.8736 - val_accuracy: 0.6316 - val_loss: 0.8735
# Epoch 25/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6341 - loss: 0.8750 - val_accuracy: 0.6284 - val_loss: 0.8813
# Epoch 26/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6351 - loss: 0.8745 - val_accuracy: 0.6346 - val_loss: 0.8682
# Epoch 27/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6315 - loss: 0.8760 - val_accuracy: 0.6365 - val_loss: 0.8718
# Epoch 28/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6341 - loss: 0.8773 - val_accuracy: 0.6284 - val_loss: 0.8717
# Epoch 29/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6354 - loss: 0.8729 - val_accuracy: 0.6354 - val_loss: 0.8719
# Epoch 30/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6368 - loss: 0.8707 - val_accuracy: 0.6336 - val_loss: 0.8700
# Epoch 31/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6341 - loss: 0.8746 - val_accuracy: 0.6385 - val_loss: 0.8675
# Epoch 32/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6365 - loss: 0.8695 - val_accuracy: 0.6355 - val_loss: 0.8721
# Epoch 33/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6366 - loss: 0.8710 - val_accuracy: 0.6337 - val_loss: 0.8676
# Epoch 34/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6352 - loss: 0.8690 - val_accuracy: 0.6344 - val_loss: 0.8744
# Epoch 35/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6377 - loss: 0.8715 - val_accuracy: 0.6355 - val_loss: 0.8631
# Epoch 36/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6364 - loss: 0.8710 - val_accuracy: 0.6365 - val_loss: 0.8672
# Epoch 37/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6353 - loss: 0.8701 - val_accuracy: 0.6361 - val_loss: 0.8723
# Epoch 38/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6356 - loss: 0.8691 - val_accuracy: 0.6339 - val_loss: 0.8712
# Epoch 39/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6407 - loss: 0.8637 - val_accuracy: 0.6370 - val_loss: 0.8674
# Epoch 40/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6363 - loss: 0.8697 - val_accuracy: 0.6368 - val_loss: 0.8677
# Epoch 41/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6367 - loss: 0.8727 - val_accuracy: 0.6389 - val_loss: 0.8685
# Epoch 42/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6377 - loss: 0.8679 - val_accuracy: 0.6349 - val_loss: 0.8647
# Epoch 43/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6380 - loss: 0.8663 - val_accuracy: 0.6370 - val_loss: 0.8642
# Epoch 44/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6417 - loss: 0.8628 - val_accuracy: 0.6403 - val_loss: 0.8683
# Epoch 45/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6350 - loss: 0.8701 - val_accuracy: 0.6372 - val_loss: 0.8613
# Epoch 46/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6387 - loss: 0.8631 - val_accuracy: 0.6390 - val_loss: 0.8652
# Epoch 47/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6366 - loss: 0.8667 - val_accuracy: 0.6393 - val_loss: 0.8693
# Epoch 48/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6429 - loss: 0.8600 - val_accuracy: 0.6382 - val_loss: 0.8719
# Epoch 49/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6445 - loss: 0.8572 - val_accuracy: 0.6265 - val_loss: 0.8766
# Epoch 50/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6412 - loss: 0.8594 - val_accuracy: 0.6339 - val_loss: 0.8774
# Epoch 51/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6380 - loss: 0.8601 - val_accuracy: 0.6370 - val_loss: 0.8671
# Epoch 52/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6432 - loss: 0.8618 - val_accuracy: 0.6397 - val_loss: 0.8642
# Epoch 53/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6385 - loss: 0.8635 - val_accuracy: 0.6408 - val_loss: 0.8588
# Epoch 54/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6413 - loss: 0.8580 - val_accuracy: 0.6395 - val_loss: 0.8617
# Epoch 55/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6424 - loss: 0.8589 - val_accuracy: 0.6350 - val_loss: 0.8668
# Epoch 56/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6425 - loss: 0.8529 - val_accuracy: 0.6362 - val_loss: 0.8676
# Epoch 57/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6401 - loss: 0.8598 - val_accuracy: 0.6368 - val_loss: 0.8649
# Epoch 58/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6427 - loss: 0.8562 - val_accuracy: 0.6362 - val_loss: 0.8687
# Epoch 59/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6438 - loss: 0.8566 - val_accuracy: 0.6385 - val_loss: 0.8628
# Epoch 60/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6412 - loss: 0.8581 - val_accuracy: 0.6371 - val_loss: 0.8609
# Epoch 61/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6430 - loss: 0.8530 - val_accuracy: 0.6371 - val_loss: 0.8694
# Epoch 62/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6462 - loss: 0.8506 - val_accuracy: 0.6413 - val_loss: 0.8611
# Epoch 63/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6424 - loss: 0.8595 - val_accuracy: 0.6346 - val_loss: 0.8640
# Epoch 64/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6425 - loss: 0.8560 - val_accuracy: 0.6391 - val_loss: 0.8687
# Epoch 65/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6407 - loss: 0.8609 - val_accuracy: 0.6362 - val_loss: 0.8643
# Epoch 66/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6400 - loss: 0.8585 - val_accuracy: 0.6362 - val_loss: 0.8642
# Epoch 67/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6432 - loss: 0.8543 - val_accuracy: 0.6362 - val_loss: 0.8609
# Epoch 68/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6401 - loss: 0.8562 - val_accuracy: 0.6394 - val_loss: 0.8642
# Epoch 69/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6462 - loss: 0.8517 - val_accuracy: 0.6367 - val_loss: 0.8675
# Epoch 70/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6412 - loss: 0.8608 - val_accuracy: 0.6394 - val_loss: 0.8529
# Epoch 71/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6409 - loss: 0.8551 - val_accuracy: 0.6408 - val_loss: 0.8587
# Epoch 72/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6457 - loss: 0.8502 - val_accuracy: 0.6400 - val_loss: 0.8646
# Epoch 73/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6441 - loss: 0.8527 - val_accuracy: 0.6394 - val_loss: 0.8570
# Epoch 74/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6455 - loss: 0.8532 - val_accuracy: 0.6391 - val_loss: 0.8666
# Epoch 75/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6455 - loss: 0.8524 - val_accuracy: 0.6315 - val_loss: 0.8736
# Epoch 76/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6441 - loss: 0.8566 - val_accuracy: 0.6349 - val_loss: 0.8598
# Epoch 77/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6457 - loss: 0.8531 - val_accuracy: 0.6357 - val_loss: 0.8621
# Epoch 78/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6440 - loss: 0.8552 - val_accuracy: 0.6416 - val_loss: 0.8568
# Epoch 79/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6428 - loss: 0.8530 - val_accuracy: 0.6387 - val_loss: 0.8663
# Epoch 80/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6435 - loss: 0.8489 - val_accuracy: 0.6391 - val_loss: 0.8635
# Epoch 81/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6441 - loss: 0.8506 - val_accuracy: 0.6369 - val_loss: 0.8642
# Epoch 82/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6449 - loss: 0.8540 - val_accuracy: 0.6431 - val_loss: 0.8603
# Epoch 83/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6450 - loss: 0.8554 - val_accuracy: 0.6401 - val_loss: 0.8593
# Epoch 84/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6402 - loss: 0.8570 - val_accuracy: 0.6423 - val_loss: 0.8615
# Epoch 85/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6423 - loss: 0.8546 - val_accuracy: 0.6357 - val_loss: 0.8618
# Epoch 86/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6452 - loss: 0.8523 - val_accuracy: 0.6361 - val_loss: 0.8769
# Epoch 87/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6453 - loss: 0.8501 - val_accuracy: 0.6416 - val_loss: 0.8653
# Epoch 88/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6465 - loss: 0.8508 - val_accuracy: 0.6425 - val_loss: 0.8562
# Epoch 89/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6432 - loss: 0.8517 - val_accuracy: 0.6399 - val_loss: 0.8647
# Epoch 90/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6444 - loss: 0.8496 - val_accuracy: 0.6414 - val_loss: 0.8598
# Epoch 91/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6463 - loss: 0.8474 - val_accuracy: 0.6398 - val_loss: 0.8622
# Epoch 92/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6436 - loss: 0.8501 - val_accuracy: 0.6342 - val_loss: 0.8744
# Epoch 93/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6447 - loss: 0.8480 - val_accuracy: 0.6420 - val_loss: 0.8615
# Epoch 94/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6451 - loss: 0.8478 - val_accuracy: 0.6408 - val_loss: 0.8649
# Epoch 95/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6452 - loss: 0.8489 - val_accuracy: 0.6429 - val_loss: 0.8625
# Checking correlation threshold: 0.9
# number of initial features: 74
# number of final features:61
# Epoch 1/100
# 2025-07-10 01:07:42.148996: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 22487040 exceeds 10% of free system memory.
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.5359 - loss: 1.1043 - val_accuracy: 0.5931 - val_loss: 0.9409
# Epoch 2/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.5923 - loss: 0.9636 - val_accuracy: 0.5983 - val_loss: 0.9212
# Epoch 3/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6004 - loss: 0.9491 - val_accuracy: 0.6024 - val_loss: 0.9250
# Epoch 4/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6068 - loss: 0.9336 - val_accuracy: 0.6136 - val_loss: 0.9039
# Epoch 5/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6079 - loss: 0.9318 - val_accuracy: 0.6140 - val_loss: 0.9069
# Epoch 6/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6129 - loss: 0.9229 - val_accuracy: 0.6138 - val_loss: 0.8959
# Epoch 7/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6150 - loss: 0.9175 - val_accuracy: 0.6172 - val_loss: 0.9013
# Epoch 8/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6156 - loss: 0.9124 - val_accuracy: 0.6156 - val_loss: 0.8872
# Epoch 9/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6216 - loss: 0.9031 - val_accuracy: 0.6236 - val_loss: 0.8859
# Epoch 10/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6156 - loss: 0.9050 - val_accuracy: 0.6202 - val_loss: 0.8941
# Epoch 11/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6232 - loss: 0.9006 - val_accuracy: 0.6217 - val_loss: 0.8835
# Epoch 12/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6196 - loss: 0.8988 - val_accuracy: 0.6268 - val_loss: 0.8822
# Epoch 13/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6261 - loss: 0.8927 - val_accuracy: 0.6271 - val_loss: 0.8831
# Epoch 14/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6226 - loss: 0.8947 - val_accuracy: 0.6245 - val_loss: 0.8854
# Epoch 15/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6268 - loss: 0.8887 - val_accuracy: 0.6283 - val_loss: 0.8854
# Epoch 16/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6305 - loss: 0.8840 - val_accuracy: 0.6305 - val_loss: 0.8806
# Epoch 17/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6284 - loss: 0.8872 - val_accuracy: 0.6262 - val_loss: 0.8776
# Epoch 18/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6264 - loss: 0.8849 - val_accuracy: 0.6294 - val_loss: 0.8708
# Epoch 19/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6308 - loss: 0.8799 - val_accuracy: 0.6324 - val_loss: 0.8724
# Epoch 20/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6285 - loss: 0.8801 - val_accuracy: 0.6273 - val_loss: 0.8766
# Epoch 21/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6321 - loss: 0.8774 - val_accuracy: 0.6250 - val_loss: 0.8800
# Epoch 22/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6354 - loss: 0.8746 - val_accuracy: 0.6270 - val_loss: 0.8851
# Epoch 23/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6318 - loss: 0.8783 - val_accuracy: 0.6291 - val_loss: 0.8696
# Epoch 24/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6330 - loss: 0.8766 - val_accuracy: 0.6363 - val_loss: 0.8705
# Epoch 25/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6322 - loss: 0.8784 - val_accuracy: 0.6328 - val_loss: 0.8795
# Epoch 26/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6311 - loss: 0.8742 - val_accuracy: 0.6299 - val_loss: 0.8778
# Epoch 27/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6326 - loss: 0.8711 - val_accuracy: 0.6315 - val_loss: 0.8763
# Epoch 28/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6332 - loss: 0.8764 - val_accuracy: 0.6327 - val_loss: 0.8681
# Epoch 29/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6341 - loss: 0.8728 - val_accuracy: 0.6304 - val_loss: 0.8741
# Epoch 30/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6350 - loss: 0.8739 - val_accuracy: 0.6290 - val_loss: 0.8712
# Epoch 31/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6339 - loss: 0.8738 - val_accuracy: 0.6339 - val_loss: 0.8650
# Epoch 32/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6337 - loss: 0.8710 - val_accuracy: 0.6336 - val_loss: 0.8785
# Epoch 33/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6337 - loss: 0.8657 - val_accuracy: 0.6366 - val_loss: 0.8682
# Epoch 34/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6342 - loss: 0.8742 - val_accuracy: 0.6372 - val_loss: 0.8778
# Epoch 35/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6350 - loss: 0.8745 - val_accuracy: 0.6376 - val_loss: 0.8703
# Epoch 36/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6369 - loss: 0.8654 - val_accuracy: 0.6362 - val_loss: 0.8664
# Epoch 37/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6377 - loss: 0.8666 - val_accuracy: 0.6386 - val_loss: 0.8580
# Epoch 38/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6368 - loss: 0.8641 - val_accuracy: 0.6359 - val_loss: 0.8661
# Epoch 39/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6379 - loss: 0.8645 - val_accuracy: 0.6348 - val_loss: 0.8610
# Epoch 40/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6380 - loss: 0.8664 - val_accuracy: 0.6304 - val_loss: 0.8773
# Epoch 41/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6404 - loss: 0.8613 - val_accuracy: 0.6302 - val_loss: 0.8706
# Epoch 42/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6392 - loss: 0.8674 - val_accuracy: 0.6367 - val_loss: 0.8628
# Epoch 43/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6396 - loss: 0.8645 - val_accuracy: 0.6356 - val_loss: 0.8638
# Epoch 44/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6408 - loss: 0.8606 - val_accuracy: 0.6389 - val_loss: 0.8587
# Epoch 45/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6413 - loss: 0.8598 - val_accuracy: 0.6359 - val_loss: 0.8676
# Epoch 46/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6399 - loss: 0.8647 - val_accuracy: 0.6375 - val_loss: 0.8623
# Epoch 47/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6400 - loss: 0.8600 - val_accuracy: 0.6387 - val_loss: 0.8595
# Epoch 48/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6386 - loss: 0.8628 - val_accuracy: 0.6409 - val_loss: 0.8571
# Epoch 49/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6383 - loss: 0.8610 - val_accuracy: 0.6393 - val_loss: 0.8613
# Epoch 50/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6390 - loss: 0.8602 - val_accuracy: 0.6333 - val_loss: 0.8700
# Epoch 51/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6389 - loss: 0.8647 - val_accuracy: 0.6376 - val_loss: 0.8613
# Epoch 52/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6389 - loss: 0.8626 - val_accuracy: 0.6399 - val_loss: 0.8602
# Epoch 53/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6414 - loss: 0.8585 - val_accuracy: 0.6394 - val_loss: 0.8583
# Epoch 54/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6413 - loss: 0.8580 - val_accuracy: 0.6336 - val_loss: 0.8682
# Epoch 55/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6422 - loss: 0.8578 - val_accuracy: 0.6404 - val_loss: 0.8583
# Epoch 56/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6392 - loss: 0.8576 - val_accuracy: 0.6344 - val_loss: 0.8693
# Epoch 57/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6419 - loss: 0.8556 - val_accuracy: 0.6370 - val_loss: 0.8691
# Epoch 58/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6431 - loss: 0.8545 - val_accuracy: 0.6360 - val_loss: 0.8666
# Epoch 59/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6393 - loss: 0.8602 - val_accuracy: 0.6355 - val_loss: 0.8629
# Epoch 60/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6388 - loss: 0.8633 - val_accuracy: 0.6364 - val_loss: 0.8699
# Epoch 61/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6421 - loss: 0.8614 - val_accuracy: 0.6385 - val_loss: 0.8649
# Epoch 62/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6392 - loss: 0.8621 - val_accuracy: 0.6393 - val_loss: 0.8599
# Epoch 63/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6450 - loss: 0.8532 - val_accuracy: 0.6369 - val_loss: 0.8598
# Epoch 64/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6404 - loss: 0.8546 - val_accuracy: 0.6375 - val_loss: 0.8683
# Epoch 65/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6440 - loss: 0.8575 - val_accuracy: 0.6376 - val_loss: 0.8621
# Epoch 66/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6430 - loss: 0.8549 - val_accuracy: 0.6403 - val_loss: 0.8611
# Epoch 67/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6420 - loss: 0.8571 - val_accuracy: 0.6407 - val_loss: 0.8578
# Epoch 68/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6459 - loss: 0.8504 - val_accuracy: 0.6378 - val_loss: 0.8581
# Epoch 69/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6408 - loss: 0.8593 - val_accuracy: 0.6421 - val_loss: 0.8555
# Epoch 70/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6433 - loss: 0.8545 - val_accuracy: 0.6408 - val_loss: 0.8564
# Epoch 71/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6443 - loss: 0.8557 - val_accuracy: 0.6360 - val_loss: 0.8631
# Epoch 72/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6428 - loss: 0.8556 - val_accuracy: 0.6382 - val_loss: 0.8557
# Epoch 73/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6423 - loss: 0.8518 - val_accuracy: 0.6364 - val_loss: 0.8604
# Epoch 74/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6434 - loss: 0.8543 - val_accuracy: 0.6376 - val_loss: 0.8637
# Epoch 75/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6414 - loss: 0.8563 - val_accuracy: 0.6414 - val_loss: 0.8539
# Epoch 76/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6416 - loss: 0.8556 - val_accuracy: 0.6395 - val_loss: 0.8576
# Epoch 77/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6434 - loss: 0.8533 - val_accuracy: 0.6364 - val_loss: 0.8639
# Epoch 78/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6469 - loss: 0.8505 - val_accuracy: 0.6379 - val_loss: 0.8558
# Epoch 79/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6433 - loss: 0.8501 - val_accuracy: 0.6373 - val_loss: 0.8613
# Epoch 80/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6427 - loss: 0.8557 - val_accuracy: 0.6392 - val_loss: 0.8626
# Epoch 81/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6439 - loss: 0.8498 - val_accuracy: 0.6365 - val_loss: 0.8610
# Epoch 82/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6413 - loss: 0.8567 - val_accuracy: 0.6413 - val_loss: 0.8646
# Epoch 83/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6441 - loss: 0.8549 - val_accuracy: 0.6380 - val_loss: 0.8604
# Epoch 84/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6438 - loss: 0.8547 - val_accuracy: 0.6398 - val_loss: 0.8587
# Epoch 85/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6445 - loss: 0.8504 - val_accuracy: 0.6390 - val_loss: 0.8634
# Epoch 86/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6450 - loss: 0.8506 - val_accuracy: 0.6416 - val_loss: 0.8599
# Epoch 87/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6433 - loss: 0.8531 - val_accuracy: 0.6398 - val_loss: 0.8653
# Epoch 88/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6470 - loss: 0.8505 - val_accuracy: 0.6375 - val_loss: 0.8617
# Epoch 89/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6416 - loss: 0.8551 - val_accuracy: 0.6362 - val_loss: 0.8587
# Epoch 90/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6457 - loss: 0.8501 - val_accuracy: 0.6411 - val_loss: 0.8530
# Epoch 91/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6476 - loss: 0.8484 - val_accuracy: 0.6396 - val_loss: 0.8636
# Epoch 92/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6454 - loss: 0.8482 - val_accuracy: 0.6379 - val_loss: 0.8585
# Epoch 93/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6437 - loss: 0.8497 - val_accuracy: 0.6334 - val_loss: 0.8622
# Epoch 94/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6458 - loss: 0.8484 - val_accuracy: 0.6375 - val_loss: 0.8577
# Epoch 95/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6459 - loss: 0.8488 - val_accuracy: 0.6418 - val_loss: 0.8602
# Epoch 96/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6441 - loss: 0.8506 - val_accuracy: 0.6374 - val_loss: 0.8649
# Epoch 97/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6441 - loss: 0.8492 - val_accuracy: 0.6415 - val_loss: 0.8600
# Epoch 98/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6506 - loss: 0.8434 - val_accuracy: 0.6369 - val_loss: 0.8734
# Epoch 99/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6454 - loss: 0.8480 - val_accuracy: 0.6438 - val_loss: 0.8561
# Epoch 100/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6457 - loss: 0.8483 - val_accuracy: 0.6378 - val_loss: 0.8601
# Checking correlation threshold: 0.85
# number of initial features: 74
# number of final features:54
# Epoch 1/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.5341 - loss: 1.1093 - val_accuracy: 0.5975 - val_loss: 0.9452
# Epoch 2/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.5955 - loss: 0.9634 - val_accuracy: 0.6046 - val_loss: 0.9327
# Epoch 3/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6002 - loss: 0.9528 - val_accuracy: 0.6085 - val_loss: 0.9178
# Epoch 4/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6083 - loss: 0.9341 - val_accuracy: 0.6136 - val_loss: 0.9082
# Epoch 5/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6085 - loss: 0.9354 - val_accuracy: 0.6176 - val_loss: 0.9055
# Epoch 6/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6155 - loss: 0.9240 - val_accuracy: 0.6179 - val_loss: 0.9078
# Epoch 7/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6193 - loss: 0.9077 - val_accuracy: 0.6202 - val_loss: 0.8995
# Epoch 8/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6157 - loss: 0.9178 - val_accuracy: 0.6250 - val_loss: 0.8918
# Epoch 9/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6192 - loss: 0.9050 - val_accuracy: 0.6290 - val_loss: 0.8987
# Epoch 10/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6234 - loss: 0.9029 - val_accuracy: 0.6248 - val_loss: 0.8954
# Epoch 11/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6229 - loss: 0.9016 - val_accuracy: 0.6260 - val_loss: 0.8837
# Epoch 12/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6253 - loss: 0.8987 - val_accuracy: 0.6285 - val_loss: 0.8853
# Epoch 13/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6266 - loss: 0.8931 - val_accuracy: 0.6306 - val_loss: 0.8800
# Epoch 14/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6238 - loss: 0.8959 - val_accuracy: 0.6259 - val_loss: 0.8821
# Epoch 15/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6264 - loss: 0.8942 - val_accuracy: 0.6299 - val_loss: 0.8867
# Epoch 16/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6281 - loss: 0.8916 - val_accuracy: 0.6301 - val_loss: 0.8847
# Epoch 17/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6305 - loss: 0.8854 - val_accuracy: 0.6339 - val_loss: 0.8812
# Epoch 18/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6300 - loss: 0.8859 - val_accuracy: 0.6253 - val_loss: 0.8872
# Epoch 19/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6290 - loss: 0.8842 - val_accuracy: 0.6301 - val_loss: 0.8827
# Epoch 20/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6285 - loss: 0.8889 - val_accuracy: 0.6323 - val_loss: 0.8854
# Epoch 21/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6308 - loss: 0.8808 - val_accuracy: 0.6290 - val_loss: 0.8776
# Epoch 22/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6297 - loss: 0.8841 - val_accuracy: 0.6340 - val_loss: 0.8765
# Epoch 23/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6286 - loss: 0.8834 - val_accuracy: 0.6331 - val_loss: 0.8700
# Epoch 24/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6329 - loss: 0.8798 - val_accuracy: 0.6356 - val_loss: 0.8728
# Epoch 25/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6332 - loss: 0.8769 - val_accuracy: 0.6324 - val_loss: 0.8810
# Epoch 26/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6351 - loss: 0.8780 - val_accuracy: 0.6378 - val_loss: 0.8656
# Epoch 27/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6337 - loss: 0.8761 - val_accuracy: 0.6335 - val_loss: 0.8697
# Epoch 28/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6351 - loss: 0.8746 - val_accuracy: 0.6369 - val_loss: 0.8686
# Epoch 29/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6341 - loss: 0.8746 - val_accuracy: 0.6351 - val_loss: 0.8721
# Epoch 30/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6363 - loss: 0.8723 - val_accuracy: 0.6283 - val_loss: 0.8859
# Epoch 31/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6362 - loss: 0.8736 - val_accuracy: 0.6318 - val_loss: 0.8760
# Epoch 32/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6335 - loss: 0.8728 - val_accuracy: 0.6317 - val_loss: 0.8673
# Epoch 33/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6347 - loss: 0.8728 - val_accuracy: 0.6345 - val_loss: 0.8706
# Epoch 34/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6329 - loss: 0.8717 - val_accuracy: 0.6385 - val_loss: 0.8730
# Epoch 35/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6368 - loss: 0.8690 - val_accuracy: 0.6350 - val_loss: 0.8742
# Epoch 36/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6365 - loss: 0.8643 - val_accuracy: 0.6358 - val_loss: 0.8718
# Epoch 37/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6384 - loss: 0.8627 - val_accuracy: 0.6367 - val_loss: 0.8687
# Epoch 38/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6401 - loss: 0.8621 - val_accuracy: 0.6343 - val_loss: 0.8767
# Epoch 39/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6363 - loss: 0.8676 - val_accuracy: 0.6354 - val_loss: 0.8690
# Epoch 40/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6356 - loss: 0.8718 - val_accuracy: 0.6328 - val_loss: 0.8772
# Epoch 41/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6406 - loss: 0.8643 - val_accuracy: 0.6357 - val_loss: 0.8676
# Epoch 42/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6410 - loss: 0.8645 - val_accuracy: 0.6353 - val_loss: 0.8749
# Epoch 43/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6388 - loss: 0.8610 - val_accuracy: 0.6347 - val_loss: 0.8752
# Epoch 44/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6361 - loss: 0.8672 - val_accuracy: 0.6374 - val_loss: 0.8635
# Epoch 45/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6391 - loss: 0.8604 - val_accuracy: 0.6389 - val_loss: 0.8651
# Epoch 46/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6374 - loss: 0.8679 - val_accuracy: 0.6351 - val_loss: 0.8649
# Epoch 47/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6373 - loss: 0.8696 - val_accuracy: 0.6347 - val_loss: 0.8668
# Epoch 48/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6431 - loss: 0.8615 - val_accuracy: 0.6379 - val_loss: 0.8695
# Epoch 49/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6426 - loss: 0.8595 - val_accuracy: 0.6373 - val_loss: 0.8665
# Epoch 50/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6389 - loss: 0.8611 - val_accuracy: 0.6386 - val_loss: 0.8687
# Epoch 51/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6396 - loss: 0.8622 - val_accuracy: 0.6391 - val_loss: 0.8626
# Epoch 52/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6411 - loss: 0.8627 - val_accuracy: 0.6387 - val_loss: 0.8681
# Epoch 53/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6425 - loss: 0.8576 - val_accuracy: 0.6390 - val_loss: 0.8672
# Epoch 54/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6402 - loss: 0.8592 - val_accuracy: 0.6421 - val_loss: 0.8604
# Epoch 55/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6398 - loss: 0.8603 - val_accuracy: 0.6339 - val_loss: 0.8794
# Epoch 56/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.6392 - loss: 0.8605 - val_accuracy: 0.6372 - val_loss: 0.8676
# Epoch 57/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6423 - loss: 0.8561 - val_accuracy: 0.6376 - val_loss: 0.8743
# Epoch 58/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6425 - loss: 0.8579 - val_accuracy: 0.6360 - val_loss: 0.8670
# Epoch 59/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6425 - loss: 0.8576 - val_accuracy: 0.6372 - val_loss: 0.8669
# Epoch 60/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6429 - loss: 0.8588 - val_accuracy: 0.6406 - val_loss: 0.8616
# Epoch 61/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6421 - loss: 0.8544 - val_accuracy: 0.6402 - val_loss: 0.8720
# Epoch 62/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6453 - loss: 0.8518 - val_accuracy: 0.6353 - val_loss: 0.8683
# Epoch 63/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6403 - loss: 0.8604 - val_accuracy: 0.6422 - val_loss: 0.8627
# Epoch 64/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6429 - loss: 0.8567 - val_accuracy: 0.6389 - val_loss: 0.8666
# Epoch 65/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6419 - loss: 0.8575 - val_accuracy: 0.6393 - val_loss: 0.8727
# Epoch 66/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - accuracy: 0.6451 - loss: 0.8524 - val_accuracy: 0.6409 - val_loss: 0.8605
# Epoch 67/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6408 - loss: 0.8619 - val_accuracy: 0.6399 - val_loss: 0.8628
# Epoch 68/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6387 - loss: 0.8555 - val_accuracy: 0.6399 - val_loss: 0.8644
# Epoch 69/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6432 - loss: 0.8571 - val_accuracy: 0.6392 - val_loss: 0.8654
# Epoch 70/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6422 - loss: 0.8555 - val_accuracy: 0.6384 - val_loss: 0.8623
# Epoch 71/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6412 - loss: 0.8555 - val_accuracy: 0.6351 - val_loss: 0.8773
# Epoch 72/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6447 - loss: 0.8493 - val_accuracy: 0.6385 - val_loss: 0.8724
# Epoch 73/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6421 - loss: 0.8552 - val_accuracy: 0.6373 - val_loss: 0.8739
# Epoch 74/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6443 - loss: 0.8536 - val_accuracy: 0.6382 - val_loss: 0.8637
# Epoch 75/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6451 - loss: 0.8518 - val_accuracy: 0.6414 - val_loss: 0.8608
# Epoch 76/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6440 - loss: 0.8524 - val_accuracy: 0.6388 - val_loss: 0.8728
# Epoch 77/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6434 - loss: 0.8543 - val_accuracy: 0.6441 - val_loss: 0.8658
# Epoch 78/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6431 - loss: 0.8606 - val_accuracy: 0.6375 - val_loss: 0.8649
# Epoch 79/100
# 2880/2880 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6443 - loss: 0.8539 - val_accuracy: 0.6418 - val_loss: 0.8643

# %%
def get_stable_val_accuracy(val_acc, method='mean_around_peak', window=5):
    """Get a stable validation accuracy metric that's less sensitive to fluctuations"""
    
    if method == 'mean_around_peak':
        maxindex = np.argmax(val_acc)
        # Safe indexing to avoid out-of-bounds
        start_idx = max(0, maxindex - window)
        end_idx = min(len(val_acc), maxindex + window + 1)
        
        stable_acc = np.mean(val_acc[start_idx:end_idx])
        stability_std = np.std(val_acc[start_idx:end_idx])
        
    return stable_acc, stability_std

# Extract data for plotting
correlation_values = []
val_accuracies = []
std_values = []

for i, H in enumerate(DNN_Histories[2:]):
    if i >= 4:
        break
    
    # Extract hyperparameters
    correlation_value = H[0]  # First hyperparameter
    
    # Get validation accuracy
    val_acc = H[1].history['val_accuracy']
    stable_acc, stability_std = get_stable_val_accuracy(val_acc, method='mean_around_peak', window=5)
    
    correlation_values.append(correlation_value)
    val_accuracies.append(stable_acc)
    std_values.append(stability_std)

# Convert to numpy arrays
correlation_values = np.array(correlation_values)
val_accuracies = np.array(val_accuracies)
std_values = np.array(std_values)


print(f'correlation cut = {correlation_values}')
print(f'val acc = {val_accuracies}')
print(f'std = {std_values}')
# Out:
# correlation cut = [0.99 0.95 0.9  0.85]
# val acc = [0.64076704 0.63917299 0.63951514 0.63971353]
# std = [0.00322697 0.00262782 0.00255439 0.00229296]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
ax = ax.flatten()  # Convert 2D array to 1D for easier indexing

for i, H in enumerate(DNN_Histories[2:]):
    if i >= 5:  # Safety check for 3x3 grid
        break
    ax[i].plot(H[1].history['accuracy'], label='Training Accuracy')
    ax[i].plot(H[1].history['val_accuracy'], label='Validation Accuracy')
    ax[i].legend()
    ax[i].set_title(f'corr cut = {H[0]}')
    ax[i].set_xlabel('Epoch')
    ax[i].set_ylabel('Accuracy')


plt.tight_layout()
plt.show()

# %%
plt.scatter(correlation_values, val_accuracies, alpha = 0.2, s = 10e4*std_values, color = 'grey', label = 'std')
c = (np.ones(val_accuracies.size) + (val_accuracies == np.max(val_accuracies)))
plt.scatter(correlation_values, val_accuracies, s = 50, c=c, cmap='PiYG')
plt.xlabel('correlation cuts')
plt.ylabel('Val Accuracy')
# plt.set_xscale('log')
# Out:
# Text(0, 0.5, 'Val Accuracy')

# %%
from matplotlib import pyplot as plt
import numpy as np
correlation_values = [0.99, 0.95, 0.9,  0.85 ,0.8,  0.75, 0.7,  0.65, 0.6,  0.5,  0.4]
val_accuracies = [0.64076704, 0.63917299, 0.63951514, 0.63971353, 0.64422348, 0.64081834, 0.64206518, 0.63503907, 0.63734218, 0.6358197, 0.63065025]
std_values = [0.00322697, 0.00262782, 0.00255439, 0.00229296, 0.00162151, 0.00221909, 0.00205959, 0.00112313, 0.00144488, 0.00224386, 0.00182646]



# Convert to numpy arrays for element-wise operations
correlation_values = np.array(correlation_values)
val_accuracies = np.array(val_accuracies)
std_values = np.array(std_values)

fig, ax = plt.subplots(figsize=(10, 6), dpi = 300)

plt.scatter(correlation_values, val_accuracies, alpha = 0.2, s = 10e4*std_values, color = 'grey', label = 'std')
c = (np.ones(val_accuracies.size) + (val_accuracies == np.max(val_accuracies)))
plt.scatter(correlation_values, val_accuracies, s = 50, c=c, cmap='PiYG')
plt.xlabel('correlation cuts')
plt.ylabel('Val Accuracy')
# plt.set_xscale('log')
# Out:
# Text(0, 0.5, 'Val Accuracy')
